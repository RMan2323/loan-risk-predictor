# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import os

# %%
train_files = [
    "One-Hot/Train_Orig_OH.csv",
    "One-Hot/Scaled/Train_Scaled_All_OH.csv",
    "One-Hot/Scaled/Train_Scaled_Cont_OH.csv",
    "One-Hot/MinMax/Train_MM_OH.csv",
    "One-Hot/MinMax/train_OH_MM_PCA15.csv",
    "One-Hot/MinMax/train_OH_MM_PCA20.csv",
    "One-Hot/MinMax/train_OH_MM_PCA25.csv",
    "One-Hot/MinMax/train_OH_MM_PCA30.csv",
    "One-Hot/MinMax/train_OH_MM_PCA35.csv",
    "IntClasses/Train_Orig_Int.csv",
    "IntClasses/Scaled/Train_Scaled_All_Int.csv",
    "IntClasses/Scaled/Train_Scaled_Cont_Int.csv",
    "IntClasses/MinMax/Train_MM_Int.csv",
    "IntClasses/MinMax/train_Int_MM_PCA10.csv",
    "IntClasses/MinMax/train_Int_MM_PCA15.csv",
    "IntClasses/MinMax/train_Int_MM_PCA20.csv",
    "IntClasses/MinMax/train_Int_MM_PCA25.csv",
]

# %%
results = []

def evaluate_model(name, model, X, y, dataset_type):
    y_pred = model.predict(X)
    acc = accuracy_score(y, y_pred)
    prec = precision_score(y, y_pred, average='binary')
    rec = recall_score(y, y_pred, average='binary')
    f1 = f1_score(y, y_pred, average='binary')

    print(f"\n{name} - {dataset_type} Evaluation")
    print("Confusion Matrix:\n", confusion_matrix(y, y_pred))
    print("Accuracy:", acc)
    print("Precision:", prec)
    print("Recall:", rec)
    print("F1 Score:", f1)

    return acc, prec, rec, f1

# %%
for path in train_files:
    print("\n" + "="*80)
    print(f"Processing dataset: {path}")
    
    train_df = pd.read_csv(path)
    valid_path = path.replace("Train", "Valid").replace("train", "valid")
    test_path = path.replace("Train", "Test").replace("train", "test")

    valid_df = pd.read_csv(valid_path)
    test_df = pd.read_csv(test_path)

    is_pca = 'PCA' in path
    target_col = -1 if is_pca else -2

    X_train = train_df.iloc[:, :target_col]
    y_train = train_df.iloc[:, target_col]

    X_valid = valid_df.iloc[:, :target_col]
    y_valid = valid_df.iloc[:, target_col]

    X_test = test_df.iloc[:, :target_col]
    y_test = test_df.iloc[:, target_col]

    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)

    name = os.path.basename(path)
    evaluate_model(name, model, X_valid, y_valid, "Validation")
    acc, prec, rec, f1 = evaluate_model(name, model, X_test, y_test, "Test")

    results.append({
        "Dataset": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1": f1
    })

results_df = pd.DataFrame(results)
results_df
# Out:
# ================================================================================
# Processing dataset: One-Hot/Train_Orig_OH.csv
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Train_Orig_OH.csv - Validation Evaluation
# Confusion Matrix:
#  [[2894  150]
#  [ 260  696]]
# Accuracy: 0.8975
# Precision: 0.8226950354609929
# Recall: 0.7280334728033473
# F1 Score: 0.7724750277469479
#
# Train_Orig_OH.csv - Test Evaluation
# Confusion Matrix:
#  [[2900  144]
#  [ 235  721]]
# Accuracy: 0.90525
# Precision: 0.8335260115606936
# Recall: 0.75418410041841
# F1 Score: 0.7918725974739154
#
# ================================================================================
# Processing dataset: One-Hot/Scaled/Train_Scaled_All_OH.csv
#
# Train_Scaled_All_OH.csv - Validation Evaluation
# Confusion Matrix:
#  [[2980   64]
#  [  82  874]]
# Accuracy: 0.9635
# Precision: 0.9317697228144989
# Recall: 0.9142259414225942
# F1 Score: 0.9229144667370643
#
# Train_Scaled_All_OH.csv - Test Evaluation
# Confusion Matrix:
#  [[2979   65]
#  [  68  888]]
# Accuracy: 0.96675
# Precision: 0.9317943336831059
# Recall: 0.9288702928870293
# F1 Score: 0.930330015715034
#
# ================================================================================
# Processing dataset: One-Hot/Scaled/Train_Scaled_Cont_OH.csv
#
# Train_Scaled_Cont_OH.csv - Validation Evaluation
# Confusion Matrix:
#  [[2979   65]
#  [  81  875]]
# Accuracy: 0.9635
# Precision: 0.9308510638297872
# Recall: 0.9152719665271967
# F1 Score: 0.9229957805907172
#
# Train_Scaled_Cont_OH.csv - Test Evaluation
# Confusion Matrix:
#  [[2979   65]
#  [  67  889]]
# Accuracy: 0.967
# Precision: 0.9318658280922432
# Recall: 0.9299163179916318
# F1 Score: 0.9308900523560208
#
# ================================================================================
# Processing dataset: One-Hot/MinMax/Train_MM_OH.csv
#
# Train_MM_OH.csv - Validation Evaluation
# Confusion Matrix:
#  [[2929  115]
#  [ 246  710]]
# Accuracy: 0.90975
# Precision: 0.8606060606060606
# Recall: 0.7426778242677824
# F1 Score: 0.7973048848961258
#
# Train_MM_OH.csv - Test Evaluation
# Confusion Matrix:
#  [[2922  122]
#  [ 238  718]]
# Accuracy: 0.91
# Precision: 0.8547619047619047
# Recall: 0.7510460251046025
# F1 Score: 0.799554565701559
#
# ================================================================================
# Processing dataset: One-Hot/MinMax/train_OH_MM_PCA15.csv
#
# train_OH_MM_PCA15.csv - Validation Evaluation
# Confusion Matrix:
#  [[2966   78]
#  [ 778  178]]
# Accuracy: 0.786
# Precision: 0.6953125
# Recall: 0.18619246861924685
# F1 Score: 0.29372937293729373
#
# train_OH_MM_PCA15.csv - Test Evaluation
# Confusion Matrix:
#  [[2959   85]
#  [ 783  173]]
# Accuracy: 0.783
# Precision: 0.6705426356589147
# Recall: 0.1809623430962343
# F1 Score: 0.28500823723228996
#
# ================================================================================
# Processing dataset: One-Hot/MinMax/train_OH_MM_PCA20.csv
#
# train_OH_MM_PCA20.csv - Validation Evaluation
# Confusion Matrix:
#  [[2848  196]
#  [ 664  292]]
# Accuracy: 0.785
# Precision: 0.5983606557377049
# Recall: 0.3054393305439331
# F1 Score: 0.40443213296398894
#
# train_OH_MM_PCA20.csv - Test Evaluation
# Confusion Matrix:
#  [[2847  197]
#  [ 674  282]]
# Accuracy: 0.78225
# Precision: 0.5887265135699373
# Recall: 0.29497907949790797
# F1 Score: 0.3930313588850175
#
# ================================================================================
# Processing dataset: One-Hot/MinMax/train_OH_MM_PCA25.csv
#
# train_OH_MM_PCA25.csv - Validation Evaluation
# Confusion Matrix:
#  [[2936  108]
#  [ 191  765]]
# Accuracy: 0.92525
# Precision: 0.8762886597938144
# Recall: 0.8002092050209205
# F1 Score: 0.8365226899945326
#
# train_OH_MM_PCA25.csv - Test Evaluation
# Confusion Matrix:
#  [[2929  115]
#  [ 170  786]]
# Accuracy: 0.92875
# Precision: 0.8723640399556049
# Recall: 0.8221757322175732
# F1 Score: 0.8465266558966074
#
# ================================================================================
# Processing dataset: One-Hot/MinMax/train_OH_MM_PCA30.csv
#
# train_OH_MM_PCA30.csv - Validation Evaluation
# Confusion Matrix:
#  [[2951   93]
#  [ 162  794]]
# Accuracy: 0.93625
# Precision: 0.895152198421646
# Recall: 0.8305439330543933
# F1 Score: 0.8616386326641345
#
# train_OH_MM_PCA30.csv - Test Evaluation
# Confusion Matrix:
#  [[2942  102]
#  [ 160  796]]
# Accuracy: 0.9345
# Precision: 0.8864142538975501
# Recall: 0.8326359832635983
# F1 Score: 0.8586839266450917
#
# ================================================================================
# Processing dataset: One-Hot/MinMax/train_OH_MM_PCA35.csv
#
# train_OH_MM_PCA35.csv - Validation Evaluation
# Confusion Matrix:
#  [[3034   10]
#  [   6  950]]
# Accuracy: 0.996
# Precision: 0.9895833333333334
# Recall: 0.9937238493723849
# F1 Score: 0.9916492693110648
#
# train_OH_MM_PCA35.csv - Test Evaluation
# Confusion Matrix:
#  [[3042    2]
#  [   4  952]]
# Accuracy: 0.9985
# Precision: 0.9979035639412998
# Recall: 0.99581589958159
# F1 Score: 0.9968586387434555
#
# ================================================================================
# Processing dataset: IntClasses/Train_Orig_Int.csv
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Train_Orig_Int.csv - Validation Evaluation
# Confusion Matrix:
#  [[2903  141]
#  [ 258  698]]
# Accuracy: 0.90025
# Precision: 0.831942789034565
# Recall: 0.7301255230125523
# F1 Score: 0.777715877437326
#
# Train_Orig_Int.csv - Test Evaluation
# Confusion Matrix:
#  [[2900  144]
#  [ 234  722]]
# Accuracy: 0.9055
# Precision: 0.8337182448036952
# Recall: 0.7552301255230126
# F1 Score: 0.7925356750823271
#
# ================================================================================
# Processing dataset: IntClasses/Scaled/Train_Scaled_All_Int.csv
#
# Train_Scaled_All_Int.csv - Validation Evaluation
# Confusion Matrix:
#  [[2972   72]
#  [ 102  854]]
# Accuracy: 0.9565
# Precision: 0.9222462203023758
# Recall: 0.893305439330544
# F1 Score: 0.9075451647183848
#
# Train_Scaled_All_Int.csv - Test Evaluation
# Confusion Matrix:
#  [[2959   85]
#  [  85  871]]
# Accuracy: 0.9575
# Precision: 0.9110878661087866
# Recall: 0.9110878661087866
# F1 Score: 0.9110878661087866
#
# ================================================================================
# Processing dataset: IntClasses/Scaled/Train_Scaled_Cont_Int.csv
#
# Train_Scaled_Cont_Int.csv - Validation Evaluation
# Confusion Matrix:
#  [[2973   71]
#  [ 102  854]]
# Accuracy: 0.95675
# Precision: 0.9232432432432433
# Recall: 0.893305439330544
# F1 Score: 0.9080276448697501
#
# Train_Scaled_Cont_Int.csv - Test Evaluation
# Confusion Matrix:
#  [[2959   85]
#  [  85  871]]
# Accuracy: 0.9575
# Precision: 0.9110878661087866
# Recall: 0.9110878661087866
# F1 Score: 0.9110878661087866
#
# ================================================================================
# Processing dataset: IntClasses/MinMax/Train_MM_Int.csv
#
# Train_MM_Int.csv - Validation Evaluation
# Confusion Matrix:
#  [[2979   65]
#  [ 198  758]]
# Accuracy: 0.93425
# Precision: 0.9210206561360875
# Recall: 0.7928870292887029
# F1 Score: 0.8521641371557054
#
# Train_MM_Int.csv - Test Evaluation
# Confusion Matrix:
#  [[2973   71]
#  [ 186  770]]
# Accuracy: 0.93575
# Precision: 0.915576694411415
# Recall: 0.805439330543933
# F1 Score: 0.8569838619922091
#
# ================================================================================
# Processing dataset: IntClasses/MinMax/train_Int_MM_PCA10.csv
#
# train_Int_MM_PCA10.csv - Validation Evaluation
# Confusion Matrix:
#  [[2872  172]
#  [ 722  234]]
# Accuracy: 0.7765
# Precision: 0.5763546798029556
# Recall: 0.24476987447698745
# F1 Score: 0.3436123348017621
#
# train_Int_MM_PCA10.csv - Test Evaluation
# Confusion Matrix:
#  [[2868  176]
#  [ 711  245]]
# Accuracy: 0.77825
# Precision: 0.5819477434679335
# Recall: 0.25627615062761505
# F1 Score: 0.3558460421205519
#
# ================================================================================
# Processing dataset: IntClasses/MinMax/train_Int_MM_PCA15.csv
#
# train_Int_MM_PCA15.csv - Validation Evaluation
# Confusion Matrix:
#  [[2927  117]
#  [ 204  752]]
# Accuracy: 0.91975
# Precision: 0.8653624856156502
# Recall: 0.7866108786610879
# F1 Score: 0.8241095890410961
#
# train_Int_MM_PCA15.csv - Test Evaluation
# Confusion Matrix:
#  [[2918  126]
#  [ 196  760]]
# Accuracy: 0.9195
# Precision: 0.8577878103837472
# Recall: 0.7949790794979079
# F1 Score: 0.8251900108577633
#
# ================================================================================
# Processing dataset: IntClasses/MinMax/train_Int_MM_PCA20.csv
#
# train_Int_MM_PCA20.csv - Validation Evaluation
# Confusion Matrix:
#  [[2950   94]
#  [ 171  785]]
# Accuracy: 0.93375
# Precision: 0.8930602957906713
# Recall: 0.8211297071129707
# F1 Score: 0.8555858310626703
#
# train_Int_MM_PCA20.csv - Test Evaluation
# Confusion Matrix:
#  [[2937  107]
#  [ 160  796]]
# Accuracy: 0.93325
# Precision: 0.8815060908084164
# Recall: 0.8326359832635983
# F1 Score: 0.8563743948359334
#
# ================================================================================
# Processing dataset: IntClasses/MinMax/train_Int_MM_PCA25.csv
#
# train_Int_MM_PCA25.csv - Validation Evaluation
# Confusion Matrix:
#  [[3039    5]
#  [   5  951]]
# Accuracy: 0.9975
# Precision: 0.9947698744769874
# Recall: 0.9947698744769874
# F1 Score: 0.9947698744769874
#
# train_Int_MM_PCA25.csv - Test Evaluation
# Confusion Matrix:
#  [[3042    2]
#  [   3  953]]
# Accuracy: 0.99875
# Precision: 0.9979057591623036
# Recall: 0.9968619246861925
# F1 Score: 0.9973835688121403
#                       Dataset  Accuracy  Precision    Recall        F1
# 0           Train_Orig_OH.csv   0.90525   0.833526  0.754184  0.791873
# 1     Train_Scaled_All_OH.csv   0.96675   0.931794  0.928870  0.930330
# 2    Train_Scaled_Cont_OH.csv   0.96700   0.931866  0.929916  0.930890
# 3             Train_MM_OH.csv   0.91000   0.854762  0.751046  0.799555
# 4       train_OH_MM_PCA15.csv   0.78300   0.670543  0.180962  0.285008
# 5       train_OH_MM_PCA20.csv   0.78225   0.588727  0.294979  0.393031
# 6       train_OH_MM_PCA25.csv   0.92875   0.872364  0.822176  0.846527
# 7       train_OH_MM_PCA30.csv   0.93450   0.886414  0.832636  0.858684
# 8       train_OH_MM_PCA35.csv   0.99850   0.997904  0.995816  0.996859
# 9          Train_Orig_Int.csv   0.90550   0.833718  0.755230  0.792536
# 10   Train_Scaled_All_Int.csv   0.95750   0.911088  0.911088  0.911088
# 11  Train_Scaled_Cont_Int.csv   0.95750   0.911088  0.911088  0.911088
# 12           Train_MM_Int.csv   0.93575   0.915577  0.805439  0.856984
# 13     train_Int_MM_PCA10.csv   0.77825   0.581948  0.256276  0.355846
# 14     train_Int_MM_PCA15.csv   0.91950   0.857788  0.794979  0.825190
# 15     train_Int_MM_PCA20.csv   0.93325   0.881506  0.832636  0.856374
# 16     train_Int_MM_PCA25.csv   0.99875   0.997906  0.996862  0.997384

# %%
best_accuracy = results_df.loc[results_df['Accuracy'].idxmax()]
best_precision = results_df.loc[results_df['Precision'].idxmax()]
best_recall = results_df.loc[results_df['Recall'].idxmax()]
best_f1 = results_df.loc[results_df['F1'].idxmax()]

print("\n" + "="*80)
print("BEST PERFORMING DATASETS")
print("Highest Accuracy: ", best_accuracy['Dataset'], f"({best_accuracy['Accuracy']:.4f})")
print("Highest Precision:", best_precision['Dataset'], f"({best_precision['Precision']:.4f})")
print("Highest Recall:   ", best_recall['Dataset'], f"({best_recall['Recall']:.4f})")
print("Highest F1 Score: ", best_f1['Dataset'], f"({best_f1['F1']:.4f})")
# Out:
# ================================================================================
# BEST PERFORMING DATASETS
# Highest Accuracy:  train_Int_MM_PCA25.csv (0.9988)
# Highest Precision: train_Int_MM_PCA25.csv (0.9979)
# Highest Recall:    train_Int_MM_PCA25.csv (0.9969)
# Highest F1 Score:  train_Int_MM_PCA25.csv (0.9974)
